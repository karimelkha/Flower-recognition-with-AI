# %% [markdown]
# # PROJET IA
# ## EL-KHARROUBI - LEFEBVRE
# ### Reconnaissance de fleurs

# %%
#import des librairies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Conv2D, Dropout, Softmax,Flatten 
from keras.layers.core import Lambda

# %%
x-special/nautilus-clipboard
cut
file:///home/vega/Documents/archive/flowers/createValidation.sh

# %%
# Extraction des images d'entraînement et de validation
# !unzip archive1.zip
# Out:
#   inflating: archive/flowers/flowers/tulip/16680930777_7e7f292fc5_n.jpg
#   inflating: archive/flowers/flowers/tulip/16680998737_6f6225fe36.jpg
#   inflating: archive/flowers/flowers/tulip/16700863150_ddaa4d89b4_n.jpg
#   inflating: archive/flowers/flowers/tulip/16702117379_c25bff70e9.jpg
#   inflating: archive/flowers/flowers/tulip/16702188449_3dacce90b2_m.jpg
#   inflating: archive/flowers/flowers/tulip/16711791713_e54bc9c1af_n.jpg
#   inflating: archive/flowers/flowers/tulip/16717320956_d4b00807f2.jpg
#   inflating: archive/flowers/flowers/tulip/16732302779_8aa56f255d_n.jpg
#   inflating: archive/flowers/flowers/tulip/16751015081_af2ef77c9a_n.jpg
#   inflating: archive/flowers/flowers/tulip/16754984282_3a801bfa50_n.jpg
#   inflating: archive/flowers/flowers/tulip/16755061382_f6531150c1_n.jpg
#   inflating: archive/flowers/flowers/tulip/16755090222_d6797d51db_n.jpg
#   inflating: archive/flowers/flowers/tulip/16756198195_13b54e70b3_n.jpg
# ...

# %%
# Création des jeux de données de validation et d'entraînement à partir des images disponibles dans le répertoire
# Categorical : on a plus de deux catégoriea

train_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory='flowers',
                                                 shuffle=True,
                                                 target_size=(280, 280), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory='flowers',
                                                 shuffle=True,
                                                 target_size=(280, 280), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-db4b8dd31916> in <module>
#       2 # Categorical : on a plus de deux catégoriea
#       3
# ----> 4 train_dataset = image_generator.flow_from_directory(batch_size=32,
#       5                                                  directory='flowers',
#       6                                                  shuffle=True,
#
# NameError: name 'image_generator' is not defined

# %%
model = tf.keras.Sequential()
inputs = Input ( shape = (  150 , 150 , 3 ))
# Réutilisation de VGG16
vgg16_features = keras.applications.vgg16.VGG16( include_top=False , weights= "imagenet",input_tensor=inputs)
vgg16_features.trainable= False


model.add(vgg16_features)
model.add(Flatten())
model.add(tf.keras.layers.Dense(512,activation='relu'))
# Le nombre de labels doit correspondre au nombre passé en paramètre de la couche d'activation de sortie
model.add(tf.keras.layers.Dense(5,activation='softmax'))

dataset = tf.keras.preprocessing.image_dataset_from_directory("flowers/",image_size=(150,150))

model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.SGD(learning_rate=1e-4, momentum = 0.9))



train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1./150,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./150)

train_generator = train_datagen.flow_from_directory(
        'flowers',
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')
validation_generator = test_datagen.flow_from_directory(
        'flowers_test',
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical')

model.fit(
        train_generator,
        steps_per_epoch=20,
        epochs=10,
        validation_data=validation_generator,
        validation_steps=10)
# Out:
# Found 4323 files belonging to 5 classes.
# Found 4323 images belonging to 5 classes.
# Found 4323 images belonging to 5 classes.
# Epoch 1/10
# 20/20 [==============================] - 161s 8s/step - loss: 1.6838 - val_loss: 1.5665
# Epoch 2/10
# 20/20 [==============================] - 166s 8s/step - loss: 1.5364 - val_loss: 1.4891
# Epoch 3/10
# 20/20 [==============================] - 155s 8s/step - loss: 1.4248 - val_loss: 1.3817
# Epoch 4/10
# 20/20 [==============================] - 160s 8s/step - loss: 1.3806 - val_loss: 1.2996
# Epoch 5/10
# 20/20 [==============================] - 160s 8s/step - loss: 1.2783 - val_loss: 1.2246
# Epoch 6/10
# 20/20 [==============================] - 160s 8s/step - loss: 1.2832 - val_loss: 1.1892
# Epoch 7/10
# 20/20 [==============================] - 160s 8s/step - loss: 1.1926 - val_loss: 1.1663
# Epoch 8/10
# 20/20 [==============================] - 160s 8s/step - loss: 1.1546 - val_loss: 1.1198
# Epoch 9/10
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KernelInterrupted: Execution interrupted by the Jupyter kernel.
# ---------------------------------------------------------------------------
# KernelInterrupted: Execution interrupted by the Jupyter kernel.

# %%
print(labels)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=886c4234-8e3d-4670-a42a-bc2bc1ff2a26' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
